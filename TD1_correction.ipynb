# %% [markdown]
# # TD 1 : Visualisation de données et Nettoyage de données

# %% [markdown]
# ### Attribute Information:

# %% [markdown]
# 1: surgery?
# 1 = Yes, it had surgery
# 2 = It was treated without surgery
#
# 2: Age
# 1 = Adult horse
# 2 = Young (< 6 months)
#
# 3: Hospital Number
# - numeric id
# - the case number assigned to the horse (may not be unique if the horse is treated > 1 time)
#
# 4: rectal temperature
# - linear
# - in degrees celsius.
# - An elevated temp may occur due to infection.
# - temperature may be reduced when the animal is in late shock
# - normal temp is 37.8
# - this parameter will usually change as the problem progresses, eg. may start out normal, then become elevated because of the lesion, passing back through the normal range as the horse goes into shock
# 5: pulse
# - linear
# - the heart rate in beats per minute
# - is a reflection of the heart condition: 30 -40 is normal for adults
# - rare to have a lower than normal rate although athletic horses may have a rate of 20-25
# - animals with painful lesions or suffering from circulatory shock may have an elevated heart rate
#
# 6: respiratory rate
# - linear
# - normal rate is 8 to 10
# - usefulness is doubtful due to the great fluctuations
#
# 7: temperature of extremities
# - a subjective indication of peripheral circulation
# - possible values:
# 1 = Normal
# 2 = Warm
# 3 = Cool
# 4 = Cold
# - cool to cold extremities indicate possible shock
# - hot extremities should correlate with an elevated rectal temp.
#
# 8: peripheral pulse
# - subjective
# - possible values are:
# 1 = normal
# 2 = increased
# 3 = reduced
# 4 = absent
# - normal or increased p.p. are indicative of adequate circulation while reduced or absent indicate poor perfusion
#
# 9: mucous membranes
# - a subjective measurement of colour
# - possible values are:
# 1 = normal pink
# 2 = bright pink
# 3 = pale pink
# 4 = pale cyanotic
# 5 = bright red / injected
# 6 = dark cyanotic
# - 1 and 2 probably indicate a normal or slightly increased circulation
# - 3 may occur in early shock
# - 4 and 6 are indicative of serious circulatory compromise
# - 5 is more indicative of a septicemia
#
# 10: capillary refill time
# - a clinical judgement. The longer the refill, the poorer the circulation
# - possible values
# 1 = < 3 seconds
# 2 = >= 3 seconds
#
# 11: pain - a subjective judgement of the horse's pain level
# - possible values:
# 1 = alert, no pain
# 2 = depressed
# 3 = intermittent mild pain
# 4 = intermittent severe pain
# 5 = continuous severe pain
# - should NOT be treated as a ordered or discrete variable!
# - In general, the more painful, the more likely it is to require surgery
# - prior treatment of pain may mask the pain level to some extent
#
# 12: peristalsis
# - an indication of the activity in the horse's gut. As the gut becomes more distended or the horse becomes more toxic, the activity decreases
# - possible values:
# 1 = hypermotile
# 2 = normal
# 3 = hypomotile
# 4 = absent
#
# 13: abdominal distension
# - An IMPORTANT parameter.
# - possible values
# 1 = none
# 2 = slight
# 3 = moderate
# 4 = severe
# - an animal with abdominal distension is likely to be painful and have reduced gut motility.
# - a horse with severe abdominal distension is likely to require surgery just tio relieve the pressure
#
# 14: nasogastric tube
# - this refers to any gas coming out of the tube
# - possible values:
# 1 = none
# 2 = slight
# 3 = significant
# - a large gas cap in the stomach is likely to give the horse discomfort
#
# 15: nasogastric reflux
# - possible values
# 1 = none
# 2 = > 1 liter
# 3 = < 1 liter
# - the greater amount of reflux, the more likelihood that there is some serious obstruction to the fluid passage from the rest of the intestine
#
# 16: nasogastric reflux PH
# - linear
# - scale is from 0 to 14 with 7 being neutral
# - normal values are in the 3 to 4 range
#
# 17: rectal examination - feces
# - possible values
# 1 = normal
# 2 = increased
# 3 = decreased
# 4 = absent
# - absent feces probably indicates an obstruction
#
# 18: abdomen
# - possible values
# 1 = normal
# 2 = other
# 3 = firm feces in the large intestine
# 4 = distended small intestine
# 5 = distended large intestine
# - 3 is probably an obstruction caused by a mechanical impaction and is normally treated medically
# - 4 and 5 indicate a surgical lesion
#
# 19: packed cell volume
# - linear
# - the # of red cells by volume in the blood
# - normal range is 30 to 50. The level rises as the circulation becomes compromised or as the animal becomes dehydrated.
#
# 20: total protein
# - linear
# - normal values lie in the 6-7.5 (gms/dL) range
# - the higher the value the greater the dehydration
#
# 21: abdominocentesis appearance
# - a needle is put in the horse's abdomen and fluid is obtained from
# the abdominal cavity
# - possible values:
# 1 = clear
# 2 = cloudy
# 3 = serosanguinous
# - normal fluid is clear while cloudy or serosanguinous indicates a compromised gut
#
# 22: abdomcentesis total protein
# - linear
# - the higher the level of protein the more likely it is to have a compromised gut. Values are in gms/dL
#
# 23: outcome
# - what eventually happened to the horse?
# - possible values:
# 1 = lived
# 2 = died
# 3 = was euthanized
#
# 24: surgical lesion?
# - retrospectively, was the problem (lesion) surgical?
# - all cases are either operated upon or autopsied so that this value and the lesion type are always known
# - possible values:
# 1 = Yes
# 2 = No
#
# 25, 26, 27: type of lesion
# - first number is site of lesion
# 1 = gastric
# 2 = sm intestine
# 3 = lg colon
# 4 = lg colon and cecum
# 5 = cecum
# 6 = transverse colon
# 7 = retum/descending colon
# 8 = uterus
# 9 = bladder
# 11 = all intestinal sites
# 00 = none
# - second number is type
# 1 = simple
# 2 = strangulation
# 3 = inflammation
# 4 = other
# - third number is subtype
# 1 = mechanical
# 2 = paralytic
# 0 = n/a
# - fourth number is specific code
# 1 = obturation
# 2 = intrinsic
# 3 = extrinsic
# 4 = adynamic
# 5 = volvulus/torsion
# 6 = intussuption
# 7 = thromboembolic
# 8 = hernia
# 9 = lipoma/slenic incarceration
# 10 = displacement
# 0 = n/a
# 28: cp_data
# - is pathology data present for this case?
# 1 = Yes
# 2 = No
# - this variable is of no significance since pathology data is not included or collected for these cases

# %% [markdown]
# Objectif : Prédire si la lesion est chirurgicale ou non (colonne 24)

# %% [markdown]
# ### Import

# %% [markdown]
# Importez les bibliothèques nécessaires et chargez le fichier `horse.csv` dans un dataframe pandas.
#
# Vous pouvez utiliser la fonction [read_csv](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) de pandas.

# %%
import pandas as pd                 # for data manipulation and analysis
import numpy as np                  # for mathematical operations
import plotly.express as px         # for data visualization
import seaborn as sns               # for data visualization
import matplotlib.pyplot as plt     # for data visualization

# %%
horses = pd.read_csv('data/horse.csv')

# %% [markdown]
# ## EXPLORATION DES DONNÉES

# %% [markdown]
# Visualisez les premières lignes, les dimensions et les types de données du dataset. A l'aide des fonctions :
#
# [pandas.head](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html)
#
# [pandas.shape](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shape.html)
#
# [pandas.dtypes](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html)
#
# [pandas.info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html)
#
# [pandas.describe](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html)

# %%
horses.head(5) # Show the first 5 rows
# Out:
#   surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0      no  adult           530101         38.5   66.0              28.0
# 1     yes  adult           534817         39.2   88.0              20.0
# 2      no  adult           530334         38.3   40.0              24.0
# 3     yes  young          5290409         39.1  164.0              84.0
# 4      no  adult           530255         37.3  104.0              35.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced             NaN            more_3_sec
# 1                 NaN              NaN   pale_cyanotic            less_3_sec
# 2              normal           normal       pale_pink            less_3_sec
# 3                cold           normal   dark_cyanotic            more_3_sec
# 4                 NaN              NaN   dark_cyanotic            more_3_sec
#
# ...

# %%
horses.info()    # Show the data types of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   surgery                299 non-null    object
#  1   age                    299 non-null    object
#  2   hospital_number        299 non-null    int64
#  3   rectal_temp            239 non-null    float64
#  4   pulse                  275 non-null    float64
#  5   respiratory_rate       241 non-null    float64
#  6   temp_of_extremities    243 non-null    object
#  7   peripheral_pulse       230 non-null    object
#  8   mucous_membrane        252 non-null    object
#  9   capillary_refill_time  267 non-null    object
#  10  pain                   244 non-null    object
#  11  peristalsis            255 non-null    object
#  12  abdominal_distention   243 non-null    object
#  13  nasogastric_tube       195 non-null    object
# ...

# %% [markdown]
# Transformez les données dans un type de données adapté si nécessaire.
#
# [pandas.astype](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html)

# %%
for col in horses.columns:
    if horses[col].dtype == 'object':
        horses[col] = horses[col].astype('category')

# %% [markdown]
# ### Visualisation des données brutes

# %% [markdown]
# bonus :
# [plt.rcParams](https://matplotlib.org/3.1.1/tutorials/introductory/customizing.html) permet de modifier les paramètres par défaut des graphiques.

# %% [markdown]
# Calculer et visualiser la fréquence d'appararition des deux modalités à prédire.
#
# Vous pouvez utiliser la fonction [value_counts](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html) de pandas.
#
# Pandas integre des modules de matplotlib pour faire rapidement des [visuels](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)

# %%
plt.rcParams.update(plt.rcParamsDefault) # Reset the default parameters

# %%
plt.theme = 'ggplot' # Theme of the plot
plt.rcParams['figure.facecolor'] = '#1e1e1e' # Background color
plt.rcParams['font.size'] = 20 # Font size
plt.rcParams['text.color'] = 'white' # Text color
plt.rcParams['axes.labelcolor'] = 'white'  # Axes label color

# %%
p = horses['surgical_lesion'].value_counts().plot(kind='pie',
                                           figsize=(10, 6),
                                           title ="Proportions de lésions chirurgicales",
                                           autopct='%1.1f%%',
                                           colors=["#e41a1c","#377eb8"],
                                           explode = (0, 0.1)
                                           )    # Plot a pie chart
plt.show()

# %%
p = horses['surgical_lesion'].value_counts().plot(kind='bar',
                                             figsize=(10, 6),
                                             title ="Proportions de lésions chirurgicales",
                                             color= ["#e41a1c", "#377eb8"],
                                             rot = 0
                                             )    # Plot a bar chart
plt.show()

# %% [markdown]
# Visualisez les modalitésd des données qualitatives :
#
# seaborn :
# [countplot](https://seaborn.pydata.org/generated/seaborn.countplot.html)
#
# plotly :
# [Bar](https://plotly.com/python/bar-charts/)

# %% [markdown]
# Bonus: Pour afficher plusieurs graph sur le meme axe :
# * sns,matplotlib : vous pouvez utiliser la fonction [subplots](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.subplots.html) de matplotlib.
# * plotly : vous pouvez utiliser la fonction [make_subplots](https://plotly.com/python/subplots/) de plotly.

# %%
# Repartition des modalités des variables qualitatives

fig, axes = plt.subplots(2, 2, figsize=(20, 10))
fig.suptitle('Repartition des modalités des variables qualitatives')
sns.countplot(ax=axes[0, 0], x="surgical_lesion", data=horses, palette="Set2")
sns.countplot(ax=axes[0, 1], x="age", data=horses, palette="Set2")
sns.countplot(ax=axes[1, 0], x="temp_of_extremities", data=horses, palette="Set2", orient='v')
sns.countplot(ax=axes[1, 1], x="mucous_membrane", data=horses, palette="Set2")
plt.show()

# %%
# Repartition des modalités des variables qualitatives avec plotly multiples
# pour  pain, peristalsis, abdominal_distention, nasogastric_reflux, nasogastric_tube, rectal_exam_feces, abdomen
#color for each bar
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=3, cols=2,
                    subplot_titles=("pain", "peristalsis", "abdominal_distention", "nasogastric_reflux", "nasogastric_tube", "rectal_exam_feces")
)

fig.add_trace(go.Bar(x=horses['pain'].value_counts().index,
                        y=horses['pain'].value_counts().values,
                        name="pain"),
                row=1, col=1)

fig.add_trace(go.Bar(x=horses['peristalsis'].value_counts().index,
                        y=horses['peristalsis'].value_counts().values,
                        name="peristalsis"),
                row=1, col=2)

fig.add_trace(go.Bar(x=horses['abdominal_distention'].value_counts().index,
                        y=horses['abdominal_distention'].value_counts().values,
                        name="abdominal_distention"),
                row=2, col=1)

fig.add_trace(go.Bar(x=horses['nasogastric_reflux'].value_counts().index,
                        y=horses['nasogastric_reflux'].value_counts().values,
                        name="nasogastric_reflux"),
                row=2, col=2)

fig.add_trace(go.Bar(x=horses['nasogastric_tube'].value_counts().index,
                        y=horses['nasogastric_tube'].value_counts().values,
                        name="nasogastric_tube"),
                row=3, col=1)

fig.add_trace(go.Bar(x=horses['rectal_exam_feces'].value_counts().index,
                        y=horses['rectal_exam_feces'].value_counts().values,
                        name="rectal_exam_feces"),
                row=3, col=2)

fig.update_layout(height=600, width=800,
                 title_text="Repartition des modalités des variables qualitatives")

fig.show()

# %% [markdown]
# Visualisez les variables quantitatives.
#
# Vous pouvez utiliser la fonction [hist](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.hist.html) de pandas.
#
# Vous pouvez utiliser la fonction [px.Histogram](https://plotly.com/python/histograms/)de plotly.express
#
# Vous pouvez utiliser la fonction [sns.histplot](https://seaborn.pydata.org/generated/seaborn.displot.html) de seaborn.

# %%
#Avec Hist de pandas

horses.hist(figsize=(20, 20), color = "#377eb8")
plt.show()

# %%
#Avec Hist de plotly

fig = make_subplots(
    rows=3, cols=2,
    subplot_titles=("rectal_temp", "pulse", "respiratory_rate", "packed_cell_volume", "total_protein", "lesion_1")
)

fig.add_trace(
    go.Histogram(
        x=horses['rectal_temp'],
        marker=dict(color='#e41a1c'),# options pour la couleur (plus d'option sur le dernier histogramme)
        name='rectal_temp'
        ),
    row=1, col=1
)

fig.add_trace(
    go.Histogram(
        x=horses['pulse'],
        marker=dict(color='#377eb8'),
        name='pulse'
        ),
    row=1, col=2
)

fig.add_trace(
    go.Histogram(
        x=horses['respiratory_rate'],
        marker=dict(color='#4daf4a'),
        name='respiratory_rate'
        ),
    row=2, col=1
)

fig.add_trace(
    go.Histogram(
        x=horses['packed_cell_volume'],
        marker=dict(color='#984ea3', opacity=0.75),
        name='packed_cell_volume'
        ),
    row=2, col=2
)

fig.add_trace(
    go.Histogram(
        x=horses['total_protein'],
        marker=dict(color='#ff7f00'),
        name='total_protein'
        ),
    row=3, col=1
)

fig.add_trace(
    go.Histogram(
        x=horses['lesion_1'],
        marker=dict(color='#ffff33', line=dict(width=2,
                                        color='DarkSlateGrey')),#ici un peu plus d'option
        name='lesion_1'
        ),
    row=3, col=2
)

fig.update_layout(height=600, width=800, title_text="Histogramme des variables quantitatives")

fig.show()

# %%
#kde=True pour avoir la densité en plus de l'histogramme
fig, ax = plt.subplots(2,2,figsize=(10, 6))
sns.histplot(data=horses, x="rectal_temp", color="#e41a1c", kde=True, ax=ax[0,0])
sns.histplot(data=horses, x="pulse", color="#377eb8", kde=True, ax=ax[0,1])
sns.histplot(data=horses, x="respiratory_rate", color="#4daf4a", kde=True, ax=ax[1,0])
sns.histplot(data=horses, x="packed_cell_volume", color="#984ea3", kde=True,)
plt.show()

# %% [markdown]
# Bonus : Ajouter des visuels qui vous semblent pertinents, pour visualiser les données.

# %% [markdown]
# ### Visualisation croisées

# %% [markdown]
# Utiliser [seaborn](https://seaborn.pydata.org/) pour visualiser les données entre elles.
# Aide:
# - Utilisez par exemple la fonction [pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html?highlight=pairplot#seaborn.pairplot)
# - Une matrice de corélation avec [plotly](https://plotly.com/python/imshow/)
# - Une matrice de corélation avec [seaborn](https://seaborn.pydata.org/examples/many_pairwise_correlations.html)

# %%
fig = sns.pairplot(horses,
              hue = "surgical_lesion",
              palette = ["#377eb8","#e41a1c"]
)
plt.show()
# Out:
# c:\Users\cdangeard\Anaconda3\envs\py10\lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %% [markdown]
# corélations entre les variables quantitatives :
# - [plotly](https://plotly.com/python/heatmap-and-contour-subplots/)
# - [seaborn](https://seaborn.pydata.org/examples/many_pairwise_correlations.html)

# %%
correlation =  round(horses.corr(numeric_only = True),  ndigits=2)

fig = px.imshow(correlation,
                text_auto=True,
                color_continuous_scale = 'Viridis',
                range_color=(0, 1),
                title='Correlation Matrix',
                width=800,
                height=800
            )

fig.update_xaxes(tickangle=40)

fig.show()

# %%
# exemple de heatmap avec seaborn (doc: https://seaborn.pydata.org/examples/many_pairwise_correlations.html)
sns.set(style="white")

# On calcule la matrice de corrélation
corr = horses.corr()

# On génère un masque pour le triangle supérieur
mask = np.triu(np.ones_like(corr, dtype=bool))

# On crée la figure matplotlib
fig, ax = plt.subplots(figsize=(20, 20))

# Une palette de couleurs
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# On dessine la heatmap avec le masque et un ratio d'aspect
sns.heatmap(corr,
            mask=mask,
            cmap=cmap,
            vmax=1,
            vmin=-1,
            center=0,
            square=True,
            linewidths=.5,
            cbar_kws={"shrink": .5},
            annot=True,
            annot_kws={"size": 20},
            fmt='.2f'
            )
plt.show()
# Out:
# C:\Users\cdangeard\AppData\Local\Temp\ipykernel_29832\1248416209.py:5: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# Réalisez un tableau de fréquence entre la variable **surgical lesion** et **temp_of_extremities**, et faites en sorte que la somme des lignes soit egal à 1.
#
# Vous pouvez utiliser la fonction [crosstab](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.crosstab.html) de pandas.

# %%
# On calcule la matrice de corrélation
pd.crosstab(
    horses.surgical_lesion,
    horses.temp_of_extremities,
    normalize="index" # Normalise par ligne
    ).style.background_gradient(cmap='Blues') # Colorisation pour le fun
# Out:
# <style type="text/css">
# #T_78d27_row0_col0, #T_78d27_row0_col1, #T_78d27_row1_col2, #T_78d27_row1_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_78d27_row0_col2, #T_78d27_row0_col3, #T_78d27_row1_col0, #T_78d27_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_78d27">
#   <thead>
#     <tr>
#       <th class="index_name level0" >temp_of_extremities</th>
#       <th id="T_78d27_level0_col0" class="col_heading level0 col0" >cold</th>
#       <th id="T_78d27_level0_col1" class="col_heading level0 col1" >cool</th>
#       <th id="T_78d27_level0_col2" class="col_heading level0 col2" >normal</th>
#       <th id="T_78d27_level0_col3" class="col_heading level0 col3" >warm</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >surgical_lesion</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
cross_df = pd.crosstab(
    horses.surgical_lesion,
    horses.temp_of_extremities, 
    normalize = "index"
    )

cross_df.plot.bar(
    stacked=True,
    title  = "Croisement des variables surgical_lesion et extremities_temp",
    figsize=(10, 6)
)

plt.show()

# %% [markdown]
# Visualisez des variables quantitative en fonction de la modalités à prédire.
#
#
# * [px.histogram](https://plotly.com/python/histograms/)
#
# * [sns.histplot](https://seaborn.pydata.org/generated/seaborn.displot.html)

# %%
fig = px.histogram(
    horses, 
    x="pulse",
    color="surgical_lesion",
    marginal="rug", #permet de rajouter les valeurs sur l'axe x
    hover_data=horses.columns
    )

fig.update_layout(
    title_text="Distribution de la variable pulse en fonction de l'issue",
    xaxis_title_text='Pulse',
    yaxis_title_text='Nombre de chevaux',
    bargap=0.2 #distance entre les bars.
)

# %%
# avec seaborn
sns.histplot(
    data=horses,
    x="pulse",
    hue="surgical_lesion",
    multiple="stack", 
    palette="Set1"
    )

plt.show()

# %% [markdown]
# ## NETTOYAGE DES DONNÉES

# %% [markdown]
# Supprimez les colonnes qui ne sont pas pertinentes pour la prédiction.

# %%
# ici j'ai utilisé la fonction drop pour supprimer les colonnes qui ne m'intéressent pas
# axis = 1 pour supprimer des colonnes
# inplace = True pour que la modification soit faite directement sur le dataframe
# surgery, hospital_number, outcome, lesion_1, lesion_2, lesion_3, cp_data

horses.drop(
    ['surgery', 'hospital_number', 'outcome',
    'lesion_1', 'lesion_2', 'lesion_3', 'cp_data'],
     axis=1, inplace=True # inplace = True pour que la modification soit faite directement sur le dataframe
     )

# %%
horses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   age                    299 non-null    object
#  1   rectal_temp            239 non-null    float64
#  2   pulse                  275 non-null    float64
#  3   respiratory_rate       241 non-null    float64
#  4   temp_of_extremities    243 non-null    object
#  5   peripheral_pulse       230 non-null    object
#  6   mucous_membrane        252 non-null    object
#  7   capillary_refill_time  267 non-null    object
#  8   pain                   244 non-null    object
#  9   peristalsis            255 non-null    object
#  10  abdominal_distention   243 non-null    object
#  11  nasogastric_tube       195 non-null    object
#  12  nasogastric_reflux     193 non-null    object
#  13  nasogastric_reflux_ph  53 non-null     float64
# ...

# %% [markdown]
# ### Etudiez les valeurs manquantes et les valeurs aberrantes.

# %% [markdown]
# Visualisez les valeurs aberrantes:
#
# par exemple un boxplot :
# * [seaborn](https://seaborn.pydata.org/examples/many_pairwise_correlations.html)
# * [plotly](https://plotly.com/python/box-plots/)
# * [pandas boxplot](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html)

# %%
horses.boxplot()
plt.title("Distribution des variables quantitatives")
plt.show()

# %%
# plotly boxplot

fig = go.Figure()

for col in horses.columns:
    if horses[col].dtype in ['int64', 'float64'] and col not in ['hospital_number', 'lesion_1', 'lesion_2', 'lesion_3']:
        fig.add_trace(go.Box(y=horses[col], name=col))

fig.update_layout(
    title_text="Distribution des variables quantitatives",
    height=800,
    width=800
)

fig.show()

# %%
#seaborn catplot
dfBox = horses[['rectal_temp', 'pulse', 'respiratory_rate', 'nasogastric_reflux_ph', 'packed_cell_volume', 'total_protein', 'abdomo_protein']]
dfBox = dfBox.melt(var_name='columns', value_name='values')

sns.catplot(x='columns', y='values', data=dfBox, kind='box', height=8, aspect=1.5)
plt.title("Distribution des variables quantitatives")
plt.show()
# Out:
# c:\Users\cdangeard\Anaconda3\envs\py10\lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %% [markdown]
# ### Valeurs manquantes
#
# Visualisez les valeurs manquantes :

# %%
na = horses.isna().sum()/horses.shape[0]*100 #calcul du pourcentage de valeurs manquantes par variable

px.bar(na.sort_values(),
         title = "Pourcentage de valeurs manquantes par variable",
         color_discrete_sequence = ["#377eb8"],
         template='ggplot2',
         range_y = [0,100],
         width=800,
         labels={'value':'%', 'index':''},
         color=None
        ).update_traces(showlegend=False).update_xaxes(tickangle=45)

# %%
na = horses.isna().sum()/horses.shape[0]*100
na.sort_values()

# A noter que vous pouvez aussi utiliser la fonction suivante pour connaitre le nombre de données non-manquantes
#horse_train.info()
# Out:
# age                       0.000000
# surgical_lesion           0.000000
# pulse                     8.026756
# packed_cell_volume        9.698997
# capillary_refill_time    10.702341
# total_protein            11.036789
# peristalsis              14.715719
# mucous_membrane          15.719064
# pain                     18.394649
# abdominal_distention     18.729097
# temp_of_extremities      18.729097
# respiratory_rate         19.397993
# rectal_temp              20.066890
# peripheral_pulse         23.076923
# rectal_exam_feces        34.113712
# nasogastric_tube         34.782609
# nasogastric_reflux       35.451505
# abdomen                  39.464883
# abdomo_appearance        55.183946
# abdomo_protein           66.220736
# nasogastric_reflux_ph    82.274247
# dtype: float64

# %%
# valeurs manquantes par ligne
horses.isna().sum(axis=1).value_counts()

px.bar(horses.isna().sum(axis=1).value_counts(),
            title = "Nombre de valeurs manquantes par ligne",
            color_discrete_sequence = ["#377eb8"],
            template='ggplot2',
            range_y = [0,100],
            width=800,
            labels={'value':'%', 'index':''},
            color=None
            ).update_traces(showlegend=False).update_xaxes(tickangle=45)

# %%
#affichier les lignes avec des valeurs manquantes
threshold = round(horses.shape[1]*0.7)

horses[horses.isna().sum(axis=1) > threshold]
# Out:
#        age  rectal_temp  pulse  respiratory_rate temp_of_extremities  \
# 17   adult         37.5   48.0              24.0                 NaN
# 28   adult          NaN    NaN               NaN                 NaN
# 39   young         39.2  146.0              96.0                 NaN
# 56   adult          NaN    NaN               NaN                 NaN
# 72   adult         37.7   56.0               NaN                 NaN
# 74   young          NaN    NaN               NaN                 NaN
# 130  adult         37.8   30.0              12.0                 NaN
# 174  adult          NaN    NaN               NaN                 NaN
# 206  adult          NaN    NaN               NaN                 NaN
# 215  adult          NaN    NaN               NaN                 NaN
# 226  young          NaN    NaN               NaN                 NaN
# 287  adult          NaN    NaN               NaN                 NaN
#
# ...

# %% [markdown]
# Pour les valeurs manquantes, une fois les variables qui en contiennent identifiés, proposez une méthode de gestion de ces valeurs manquantes.
#
# [Package sklearn](https://scikit-learn.org/stable/modules/impute.html)
#
# Pour aller plus loin :
# [Cours de François Husson (Agrocampus)](https://husson.github.io/img/cours_missMDA_Sp%C3%A9_Stat.pdf)

# %%
from sklearn.impute import SimpleImputer

imp = SimpleImputer(missing_values=np.nan,
                    strategy='most_frequent',
                    )

horsesImputed = pd.DataFrame(
    imp.fit_transform(horses),
    columns=horses.columns
    )

horsesImputed.head(5)
# Out:
#      age rectal_temp  pulse respiratory_rate temp_of_extremities  \
# 0  adult        38.5   66.0             28.0                cool
# 1  adult        39.2   88.0             20.0                cool
# 2  adult        38.3   40.0             24.0              normal
# 3  young        39.1  164.0             84.0                cold
# 4  adult        37.3  104.0             35.0                cool
#
#   peripheral_pulse mucous_membrane capillary_refill_time          pain  \
# 0          reduced     normal_pink            more_3_sec  extreme_pain
# 1           normal   pale_cyanotic            less_3_sec     mild_pain
# 2           normal       pale_pink            less_3_sec     mild_pain
# 3           normal   dark_cyanotic            more_3_sec     depressed
# 4           normal   dark_cyanotic            more_3_sec     mild_pain
#
#   peristalsis  ... nasogastric_tube nasogastric_reflux nasogastric_reflux_ph  \
# ...

# %%
# imputer perso compatible avec sklearn
# necéssite d'implémenter les méthodes fit, transform et fit_transform
# pour plus d'infos: https://scikit-learn.org/stable/developers/develop.html

class inputer_perso():
    def __init__(self) -> None:
        pass
    
    def fit(self, X, y=None):
        self.X = X
        return self
    
    def transform(self, X, y=None):
        X = X.copy()
        for col in X.columns:
            if X[col].dtype != 'float64':
                X[col] = X.loc[:,col].fillna(X[col].mode()[0])
            else:
                X[col] = X.loc[:,col].fillna(X[col].mean())
        return X
    
    def fit_transform(self, X, y=None):
        self.fit(X)
        return self.transform(X)

# %%
# Regles de imputation des données
# 1. Si la variable a plus de 40% de valeurs manquantes, on la supprime
# 2. Si la variable est qualitative, on remplace les valeurs manquantes par le mode
# 3. Si la variable est quantitative, on remplace les valeurs manquantes par la médiane

def imputation_simple_data(df):
    print("Number of rows and columns: ", df.shape,
          "\n"
          "Number of missing values: ", df.isnull().sum().sum()
    )
    df = df.copy()
    # Drop columns with more than 40% missing values
    df = df.dropna(thresh=len(df)*0.6, axis=1)
    
    # Fill missing values with mode for categorical variables and median for numerical variables
    for col in df.columns:
        if df[col].dtype != 'float64':
            df[col] = df[col].fillna(df[col].mode()[0])
            print(col, ":", df[col].mode()[0])
        else:
            df[col] = df[col].fillna(df[col].mean())
            print(col, ":", df[col].mean())
    
    print("Data cleaned!"
          "\n"
          "Number of rows and columns: ", df.shape,
          "\n"
          "Number of missing values: ", df.isnull().sum().sum()
    )
    return df

horsesImputed = imputation_simple_data(horses)
horsesImputed.head(5)
# Out:
# Number of rows and columns:  (299, 21)
# Number of missing values:  1602
# age : adult
# rectal_temp : 38.16861924686192
# pulse : 72.0
# respiratory_rate : 30.46058091286307
# temp_of_extremities : cool
# peripheral_pulse : normal
# mucous_membrane : normal_pink
# capillary_refill_time : less_3_sec
# pain : mild_pain
# peristalsis : hypomotile
# abdominal_distention : none
# nasogastric_tube : slight
# nasogastric_reflux : none
# rectal_exam_feces : absent
# abdomen : distend_large
# packed_cell_volume : 46.30740740740741
# total_protein : 24.27443609022556
# surgical_lesion : yes
# Data cleaned!
# Number of rows and columns:  (299, 18)
# Number of missing values:  0
#      age  rectal_temp  pulse  respiratory_rate temp_of_extremities  \
# 0  adult         38.5   66.0              28.0                cool
# 1  adult         39.2   88.0              20.0                cool
# 2  adult         38.3   40.0              24.0              normal
# ...

# %%
horsesImputed = inputer_perso().fit_transform(horses)
horsesImputed.head(5)
# Out:
#      age  rectal_temp  pulse  respiratory_rate temp_of_extremities  \
# 0  adult         38.5   66.0              28.0                cool
# 1  adult         39.2   88.0              20.0                cool
# 2  adult         38.3   40.0              24.0              normal
# 3  young         39.1  164.0              84.0                cold
# 4  adult         37.3  104.0              35.0                cool
#
#   peripheral_pulse mucous_membrane capillary_refill_time          pain  \
# 0          reduced     normal_pink            more_3_sec  extreme_pain
# 1           normal   pale_cyanotic            less_3_sec     mild_pain
# 2           normal       pale_pink            less_3_sec     mild_pain
# 3           normal   dark_cyanotic            more_3_sec     depressed
# 4           normal   dark_cyanotic            more_3_sec     mild_pain
#
#   peristalsis  ... nasogastric_tube nasogastric_reflux nasogastric_reflux_ph  \
# ...

# %%
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer

# On extrait les numeros de colones des variables quantitatives
colsQt = horsesImputed.select_dtypes(include=['int64', 'float64']).columns
colsQl = horsesImputed.select_dtypes(exclude=['int64', 'float64']).columns
num_colsQt = horsesImputed.columns.get_indexer(colsQt)
num_colsQl = horsesImputed.columns.get_indexer(colsQl)

# On crée un imputer pour les variables quantitatives
impQt = IterativeImputer(max_iter=10, random_state=0, initial_strategy='median')
impQt.fit(horsesImputed.iloc[:, num_colsQt])

# On crée un imputer pour les variables qualitatives
impQl = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
impQl.fit(horsesImputed.iloc[:, num_colsQl])

# On transforme les données
horsesImputed.iloc[:, num_colsQt] = impQt.transform(horsesImputed.iloc[:, num_colsQt])
horsesImputed.iloc[:, num_colsQl] = impQl.transform(horsesImputed.iloc[:, num_colsQl])

horsesImputed.head(5)
# Out:
# C:\Users\cdangeard\AppData\Local\Temp\ipykernel_3440\1778625373.py:20: DeprecationWarning:
#
# In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#      age  rectal_temp  pulse  respiratory_rate temp_of_extremities  \
# 0  adult         38.5   66.0              28.0                cool
# 1  adult         39.2   88.0              20.0                cool
# 2  adult         38.3   40.0              24.0              normal
# 3  young         39.1  164.0              84.0                cold
# 4  adult         37.3  104.0              35.0                cool
#
#   peripheral_pulse mucous_membrane capillary_refill_time          pain  \
# 0          reduced     normal_pink            more_3_sec  extreme_pain
# 1           normal   pale_cyanotic            less_3_sec     mild_pain
# ...
